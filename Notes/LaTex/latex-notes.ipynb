# %% [markdown]
# # TexWorks

# %% [markdown]
# **Code**

# %%
pdflatex.exe main.tex           - compile to pdf

# %% [markdown]
# # Compile script

# %%
taskkill.exe /IM TeXworks.exe /F
pdflatex.exe main.tex
TeXworks.exe main.pdf

# %% [markdown]
# # Classes

# %% [markdown]
# ## Two column report
#
# ![image.png](attachment:image.png)

# %%
\documentclass[9pt,a4paper]{IEEEtran}
\usepackage{graphics,epsfig,amsmath,graphpap}
\usepackage{multirow,cite,hyperref}
\usepackage[utf8]{inputenc}
\usepackage[english]{babel}
\graphicspath{ {./Images/} }
\usepackage{float}
\usepackage{placeins}
\raggedbottom
\usepackage{blindtext} %texts for example
\usepackage{ragged2e}
\usepackage[a4paper]{geometry}
\usepackage{multicol,lipsum} % Provides flexible two-column layouts
\usepackage{flushend} % Aligns columns properly

\begin{document}
\end{document}

# %% [markdown]
# ## Cover and single column
#
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png)

# %%
\documentclass[12pt]{article}
\usepackage[english]{babel}
\usepackage{amsmath}
\usepackage{array}
\usepackage{caption}
\usepackage{comment}
\usepackage{commath}
\usepackage{eufrak}
\usepackage{floatrow}
\usepackage{amsmath, amssymb}
\floatsetup[figure]{capposition=bottom}
\floatsetup[table]{capposition=top}
\usepackage{fullpage}
\usepackage{geometry}
\usepackage{graphicx}
\usepackage{hyperref}
\usepackage{layout}
\usepackage{mwe}
\usepackage{physics}
\usepackage{subcaption}
\usepackage[table]{xcolor}
\usepackage{upgreek}
\setcounter{secnumdepth}{3}
\usepackage{array}

\geometry{
    a4paper,
    left=20mm,
    right=20mm,
    top =20mm,
}

\setlength\parindent{0em}
\setlength\parskip{0em}

\begin{document}

\begin{titlepage}
\newcommand{\HRule}{\rule{\linewidth}{0.5mm}}
\newcommand{\un}[1]{\ensuremath{\ \mathrm{#1}}}
\newcommand{\ex}[1]{\ensuremath{\times10^{#1}}}
\center
\textsc{\LARGE BMEN01 - Biomedical Signal Processing}\\[2cm]
\HRule\\[1.0cm]
{\huge\bfseries AF Detector Project}\\[0.4cm]
\HRule\\[1.5cm]
\begin{minipage}{0.4\textwidth}
\begin{flushleft}
\large
\textit{Authors}\\
\textsc{Jonathan Olsson}\\
\textsc{Ossian Erixon}\\
\end{flushleft}
\end{minipage}
\begin{minipage}{0.4\textwidth}
\begin{flushright}
\large
\textit{Supervisor}\\
\textsc{Martin Stridh}\\
\end{flushright}
\end{minipage}
 \vfill\vfill\vfill\vfill
\includegraphics[width=0.8\textwidth]{Lund.png}
\vfill\vfill\vfill
{Turned in: 20/5-25}
\vfill
\end{titlepage}

\renewcommand{\contentsname}{Table of contents}
\tableofcontents
\newpage

\end{document}

# %% [markdown]
# ## Class customization

# %% [markdown]
# ### Change paper margins

# %%
\usepackage[a4paper,margin=1cm]{geometry}

# %% [markdown]
# # Load .tex files

# %%
\input{location of .tex file}

# %% [markdown]
# # Inserts

# %% [markdown]
# ## Images

# %% [markdown]
# ### Single

# %%
\begin{figure}[h]
\begin{center}
\includegraphics[width=7.5cm]{Images/Updated_figure1.png}
\caption{example image}
\label{imagelabel}
\end{center}
\end{figure}

# %% [markdown]
# ### Stacked images

# %%
\begin{figure}[h]
\centering

\begin{subfigure}{0.8\linewidth}
    \centering
    \includegraphics[width=\linewidth]{Images/step2/air1.png}
    \caption{Add trend operator of 24, and $a_{1}$.}
    \label{}
\end{subfigure}

\begin{subfigure}{0.8\linewidth}
    \centering
    \includegraphics[width=\linewidth]{Images/step2/air2.png}
    \caption{Add $c_{1}$.}
    \label{}
\end{subfigure}

\caption{ARMA air temperature.}
\label{armaestair}
\end{figure}

# %% [markdown]
# ### Paired images

# %%
\begin{figure}[h]
\centering
\begin{minipage}{0.48\textwidth}
    \centering
    \includegraphics[width=\linewidth]{}
    \caption*{}
    
    \includegraphics[width=\linewidth]{}
    \caption*{}
    
    \includegraphics[width=\linewidth]{}
    \caption*{}
\end{minipage}
\hfill
\begin{minipage}{0.48\textwidth}
    \centering
    \includegraphics[width=\linewidth]{}
    \caption*{}
    
    \includegraphics[width=\linewidth]{}
    \caption*{}
    
    \includegraphics[width=\linewidth]{}
    \caption*{}
\end{minipage}

\caption{}
\label{}
\end{figure}

# %% [markdown]
# ### 3x3 images

# %%
1 2 3
4 5 6
7 8 9

# %%
\begin{figure}[htbp]
\centering

\begin{minipage}{0.32\textwidth}
    \centering
    \includegraphics[width=\linewidth]{img1}
    \caption*{(a)}
\end{minipage}
\hfill
\begin{minipage}{0.32\textwidth}
    \centering
    \includegraphics[width=\linewidth]{img2}
    \caption*{(b)}
\end{minipage}
\hfill
\begin{minipage}{0.32\textwidth}
    \centering
    \includegraphics[width=\linewidth]{img3}
    \caption*{(c)}
\end{minipage}

\vspace{0.3cm}

\begin{minipage}{0.32\textwidth}
    \centering
    \includegraphics[width=\linewidth]{img4}
    \caption*{(d)}
\end{minipage}
\hfill
\begin{minipage}{0.32\textwidth}
    \centering
    \includegraphics[width=\linewidth]{img5}
    \caption*{(e)}
\end{minipage}
\hfill
\begin{minipage}{0.32\textwidth}
    \centering
    \includegraphics[width=\linewidth]{img6}
    \caption*{(f)}
\end{minipage}

\vspace{0.3cm}

\begin{minipage}{0.32\textwidth}
    \centering
    \includegraphics[width=\linewidth]{img7}
    \caption*{(g)}
\end{minipage}
\hfill
\begin{minipage}{0.32\textwidth}
    \centering
    \includegraphics[width=\linewidth]{img8}
    \caption*{(h)}
\end{minipage}
\hfill
\begin{minipage}{0.32\textwidth}
    \centering
    \includegraphics[width=\linewidth]{img9}
    \caption*{(i)}
\end{minipage}

\caption{3x3 panel figure}
\label{fig:3x3}
\end{figure}

# %% [markdown]
# ## Math

# %%
# Math outside text
\[ insert maths here \]

# Math inside text
(\ insert math here \)

# Integrals
\[ \int\limits_0^1 x^2 + y^2 \ dx \]

# Labelled equations
\begin{equation}
\label{power}
P=UI \Leftrightarrow U=\frac{P}{I}
\end{equation}

# Works best in double column and with large equations
\begin{equation}
\begin{aligned}
    A(z)= 1 - 1.56\,z^{-1} + 0.61\,z^{-2} - 0.18\,z^{-23}\\
         + 0.07\,z^{-24} + 0.12\,z^{-25}\\
         - 0.03\,z^{-26} - 0.02\,z^{-47}\\
    C(z)= 1 - 0.03\,z^{-1}\\
    \\
\end{aligned}
\end{equation}

# %% [markdown]
# ## Symbols

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %%
\alpha \beta \gamma \rho \sigma \delta \epsilon

# x
\times

# hat
\hat{x}

# %% [markdown]
# ## Table

# %%
\begin{table}[h]
\begin{center}
\caption{}
\renewcommand\arraystretch{1.25}
\begin{tabular}{|l|c|c|c|c|} \hline
 & Grupp 1 & Grupp 2 \\ \hline\hline
Resultat 1 &957  & 510 \\ \hline
Resultat 2 & 69 & 55  \\ \hline
Resultat 3 & 70 & 94 \\ \hline
Resultat 4  & 8 & 9 \\ \hline
\end{tabular}
\label{tableData}
\end{center}
\end{table}

# Invisible outline
\begin{center}
\begin{tabular}{l p{15cm}} % Adjust the width (10cm) as needed
    data\textunderscore inspection.m & Main script for inspecting data\\
    features\textunderscore test.m & Main script for evaluating detection parameters\\
    SVM.m & Main script for using the SVM model\\
    voting.m & Main script for using the voting-based model  
\end{tabular}
\end{center}

# %% [markdown]
# ## Bullet lists

# %%
\begin{itemize}
  \item \textbf{example bullet}
\end{itemize}

# %% [markdown]
# ## Top right texts on every page

# %%
\markboth{EEMN05 - EMC, Noise and Noise Reduction}{}

# %% [markdown]
# # Text styles

# %%
# Italic
\textit{}

% underline
\underline{}

# %% [markdown]
# # Subscripts and superscripts

# %%
\[ a_1^2 + a_2^2 = a_3^2 \]
\[ x^{2 \alpha} - 1 = y_{ij} + y_{ij}  \]

# In text
This is text$^{like\ this}$.

# %% [markdown]
# # Titles

# %%
\title{Biomedical Signal Processing - AF Detector Project}
\author{Jonathan Olsson, Ossian Erixon}
\date{15 October 2025}
\maketitle

# %% [markdown]
# # Sections

# %%
\section{section title}

\subsection{subsection title}

\section*{section without numbering}

\subsection*{subsection without numbering}

# %% [markdown]
# # Text columns

# %% [markdown]
# ## Mix single-column and double

# %%
\onecolumn

\begin{multicols}{2}
\lipsum[2]
\end{multicols}

# %% [markdown]
# ## Narrow middle column

# %%
\usepackage{geometry}

\newgeometry{margin=3cm}
% --- your narrow text here ---
\restoregeometry

# %% [markdown]
# # In-text labels
# Allows you to label specific parts of the text to cite

# %% [markdown]
# # In-text links

# %%
\href{https://archive.physionet.org/physiotools/matlab/wfdb-app-matlab/}{\textit{WFDB ToolBox}}

# %%
\label{secIntroduction}

# %% [markdown]
# # Bibliography

# %%
\begin{thebibliography}{9}

    \bibitem{AFlit} Sörnmo, L. (2018). Atrial Fibrillation from an Engineering Perspective. Springer. [Accessed 14 May. 2025]

    \bibitem{para} MathWorks. (n.d.). Parallel Computing Toolbox – MATLAB. [Accessed 14 May. 2025], \url{https://se.mathworks.com/products/parallel-computing.html}

\end{thebibliography}

# %%
And to cite:
\cite{AFlit}

# %% [markdown]
# # Other

# %% [markdown]
# ## Random text

# %% [markdown]
# ## Multiblock comment

# %%
% Add this to main.tex at start
\newcommand{\mycomment}[1]{}

% Usage:
\mycomment{
This line of text won't show

This one won't either
}

# %% [markdown]
# ## Quick % ---- % paste

# %%
%--------------------------------------------------------------------------------------------------------%

# %%
\lipsum[1]
